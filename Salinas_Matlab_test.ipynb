# %%
# %matplotlib notebook
from skimage import data, io
import numpy as np
import scipy.io
from matplotlib import pyplot as plt

# %%
Salinas = scipy.io.loadmat('dataset/Salinas/Salinas.mat')
npSalinas=np.array(Salinas['salinas'])

print ("Height:\t\t%i pixels\nWidth:\t\t%i pixels\nChannels:\t%i" % npSalinas.shape)
print ("data-type: %s " % npSalinas.dtype)
# Out:
# Height:		512 pixels
# Width:		217 pixels
# Channels:	224
# data-type: int16

# %%
plt.imshow(npSalinas[:,:,185])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Salinas_corrected = scipy.io.loadmat('dataset/Salinas/Salinas_corrected.mat')
npSalinas_corrected=np.array(Salinas_corrected['salinas_corrected'])

print ("Height:\t\t%i pixels\nWidth:\t\t%i pixels\nChannels:\t%i" % npSalinas_corrected.shape)
print ("data-type: %s " % npSalinas_corrected.dtype)
# Out:
# Height:		512 pixels
# Width:		217 pixels
# Channels:	204
# data-type: int16

# %%
Salinas_gt = scipy.io.loadmat('dataset/Salinas/Salinas_gt.mat')

npSalinas_gt=np.array(Salinas_gt['salinas_gt'])

npSalinas_gt.shape
# Out:
# (512, 217)

# %%
plt.imshow(npSalinas_gt)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
